# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/Users/jimenagonzalez/research/DSPL/Simulations-Double-Source-Gravitational-Lensing/ellipticity/shape_redshift.csv')
data = data.head(1000000)

# %%
data = data[data['DNF_ZMEAN_SOF'] > 0.01]
data = data[data['SOF_CM_G_1'] > -5000]
data = data[data['SOF_CM_G_1'] > -5000]
data
# Out:
#         COADD_OBJECT_ID  DNF_ZMEAN_SOF  SOF_CM_G_1  SOF_CM_G_2
# 0             244607706       0.504381   -0.079170    0.005996
# 1             244600942       0.776298   -0.170987   -0.132813
# 2             218650301       0.844041   -0.321382   -0.109488
# 3             245276800       0.838277    0.054696   -0.002785
# 4             245289004       0.952009    0.311295   -0.212472
# ...                 ...            ...         ...         ...
# 999995        382076206       0.820668   -0.325684   -0.155712
# 999996        381963589       0.733290   -0.275322    0.074963
# 999997        381333445       0.914966    0.046818   -0.475831
# 999998        382205027       0.592071   -0.097260    0.025763
# 999999        382000182       1.120011   -0.245337   -0.194175
#
# [998534 rows x 4 columns]

# %%
plt.figure(figsize=(11,15))

plt.subplot(3, 2, 1)
plt.plot(data['DNF_ZMEAN_SOF'], data['SOF_CM_G_1'], 'bo')
plt.xlabel('Redshift')
plt.ylabel('G1')
plt.xlim(0,3)

plt.subplot(3, 2, 2)
plt.plot(data['DNF_ZMEAN_SOF'], data['SOF_CM_G_2'], 'ro')
plt.xlabel('Redshift')
plt.ylabel('G2')
plt.xlim(0,3)

plt.subplot(3, 2, 3)
plt.plot(data['DNF_ZMEAN_SOF'], data['SOF_CM_G_1'], 'bo')
plt.xlabel('Redshift')
plt.ylabel('G1')
plt.xlim(0,7)

plt.subplot(3, 2, 4)
plt.plot(data['DNF_ZMEAN_SOF'], data['SOF_CM_G_2'], 'ro')
plt.xlabel('Redshift')
plt.ylabel('G2')
plt.xlim(0,7)

plt.subplot(3, 2, 5)
plt.plot(data['DNF_ZMEAN_SOF'], data['SOF_CM_G_1'], 'bo')
plt.xlabel('Redshift')
plt.ylabel('G1')

plt.subplot(3, 2, 6)
plt.plot(data['DNF_ZMEAN_SOF'], data['SOF_CM_G_2'], 'ro')
plt.xlabel('Redshift')
plt.ylabel('G2')

plt.show()

# %%
plt.figure(figsize=(6,6))
plt.plot(data['SOF_CM_G_1'], data['SOF_CM_G_2'], 'bo')
plt.xlabel('G1')
plt.ylabel('G2')
plt.show()
